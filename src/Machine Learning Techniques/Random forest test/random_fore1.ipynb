# %%
import numpy as np

from sklearn import datasets

from sklearn.model_selection import train_test_split

from randomForest import randomForest

def accuracy(a_true, a_pred):
   
    accuracy = np.sum(a_true == a_pred) / len(a_true)
    
    return accuracy

data = datasets.load_breast_cancer()

X = data.data

a = data.target

X_train, X_test, a_train, a_test = train_test_split(X, a, test_size=0.2, random_state=1234)

clf = randomForest(n_trees=3, max_depth=10)

clf.fit(X_train, a_train)

a_pred = clf.predict(X_test)

acc = accuracy(y_test, a_pred)

print ("Accuracy:", acc)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       3 from sklearn import datasets
#       5 from sklearn.model_selection import train_test_split
# ----> 7 from randomForest import randomForest
#       9 def accuracy(a_true, a_pred):
#      11     accuracy = np.sum(a_true == a_pred) / len(a_true)
#
# ModuleNotFoundError: No module named 'randomForest'
